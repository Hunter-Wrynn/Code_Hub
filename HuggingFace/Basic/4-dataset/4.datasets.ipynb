# %%
from datasets import *

# %%
import os
os.environ['http_proxy'] = "http://127.0.0.1:7890"
os.environ['https_proxy'] = "http://127.0.0.1:7890"

# %% [markdown]
# # datasets 基本使用

# %% [markdown]
# ## 加载在线数据集

# %%
datasets = load_dataset("madao33/new-title-chinese")
datasets
# Out:
# train.csv:   0%|          | 0.00/22.6M [00:00<?, ?B/s]
# dev.csv:   0%|          | 0.00/6.49M [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/5850 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1679 [00:00<?, ? examples/s]
# DatasetDict({
#     train: Dataset({
#         features: ['title', 'content'],
#         num_rows: 5850
#     })
#     validation: Dataset({
#         features: ['title', 'content'],
#         num_rows: 1679
#     })
# })

# %% [markdown]
# ## 加载数据集合集中的某一项任务

# %%
boolq_dataset = load_dataset("super_glue", "boolq")
boolq_dataset
# Out:
# README.md:   0%|          | 0.00/18.2k [00:00<?, ?B/s]
# super_glue.py:   0%|          | 0.00/30.7k [00:00<?, ?B/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 boolq_dataset = load_dataset("super_glue", "boolq")
#       2 boolq_dataset
#
# File ~/miniconda3/envs/llmadp3/lib/python3.9/site-packages/datasets/load.py:2129, in load_dataset(path, name, data_dir, data_files, split, cache_dir, features, download_config, download_mode, verification_mode, keep_in_memory, save_infos, revision, token, streaming, num_proc, storage_options, trust_remote_code, **config_kwargs)
#    2124 verification_mode = VerificationMode(
#    2125     (verification_mode or VerificationMode.BASIC_CHECKS) if not save_infos else VerificationMode.ALL_CHECKS
#    2126 )
#    2128 # Create a dataset builder
# -> 2129 builder_instance = load_dataset_builder(
#    2130     path=path,
#    2131     name=name,
#    2132     data_dir=data_dir,
#    2133     data_files=data_files,
#    2134     cache_dir=cache_dir,
#    2135     features=features,
#    2136     download_config=download_config,
#    2137     download_mode=download_mode,
#    2138     revision=revision,
#    2139     token=token,
#    2140     storage_options=storage_options,
#    2141     trust_remote_code=trust_remote_code,
#    2142     _require_default_config_name=name is None,
#    2143     **config_kwargs,
#    2144 )
#    2146 # Return iterable dataset in case of streaming
#    2147 if streaming:
#
# File ~/miniconda3/envs/llmadp3/lib/python3.9/site-packages/datasets/load.py:1849, in load_dataset_builder(path, name, data_dir, data_files, cache_dir, features, download_config, download_mode, revision, token, storage_options, trust_remote_code, _require_default_config_name, **config_kwargs)
#    1847     download_config = download_config.copy() if download_config else DownloadConfig()
#    1848     download_config.storage_options.update(storage_options)
# -> 1849 dataset_module = dataset_module_factory(
#    1850     path,
#    1851     revision=revision,
#    1852     download_config=download_config,
#    1853     download_mode=download_mode,
#    1854     data_dir=data_dir,
#    1855     data_files=data_files,
#    1856     cache_dir=cache_dir,
#    1857     trust_remote_code=trust_remote_code,
#    1858     _require_default_config_name=_require_default_config_name,
#    1859     _require_custom_configs=bool(config_kwargs),
#    1860 )
#    1861 # Get dataset builder class from the processing script
#    1862 builder_kwargs = dataset_module.builder_kwargs
#
# File ~/miniconda3/envs/llmadp3/lib/python3.9/site-packages/datasets/load.py:1731, in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, cache_dir, trust_remote_code, _require_default_config_name, _require_custom_configs, **download_kwargs)
#    1726                 else:
#    1727                     raise FileNotFoundError(
#    1728                         f"Couldn't find any data file at {relative_to_absolute_path(path)}. "
#    1729                         f"Couldn't find '{path}' on the Hugging Face Hub either: {type(e1).__name__}: {e1}"
#    1730                     ) from None
# -> 1731             raise e1 from None
#    1732 elif trust_remote_code:
#    1733     raise FileNotFoundError(
#    1734         f"Couldn't find a dataset script at {relative_to_absolute_path(combined_path)} or any data file in the same directory."
#    1735     )
#
# File ~/miniconda3/envs/llmadp3/lib/python3.9/site-packages/datasets/load.py:1674, in dataset_module_factory(path, revision, download_config, download_mode, dynamic_modules_path, data_dir, data_files, cache_dir, trust_remote_code, _require_default_config_name, _require_custom_configs, **download_kwargs)
#    1672             pass
#    1673     # Otherwise we must use the dataset script if the user trusts it
# -> 1674     return HubDatasetModuleFactoryWithScript(
#    1675         path,
#    1676         commit_hash=commit_hash,
#    1677         download_config=download_config,
#    1678         download_mode=download_mode,
#    1679         dynamic_modules_path=dynamic_modules_path,
#    1680         trust_remote_code=trust_remote_code,
#    1681     ).get_module()
#    1682 except EntryNotFoundError:
#    1683     # Use the infos from the parquet export except in some cases:
#    1684     if data_dir or data_files or (revision and revision != "main"):
#
# File ~/miniconda3/envs/llmadp3/lib/python3.9/site-packages/datasets/load.py:1344, in HubDatasetModuleFactoryWithScript.get_module(self)
#    1333         _create_importable_file(
#    1334             local_path=local_path,
#    1335             local_imports=local_imports,
#    (...)
#    1341             download_mode=self.download_mode,
#    1342         )
#    1343     else:
# -> 1344         raise ValueError(
#    1345             f"Loading {self.name} requires you to execute the dataset script in that"
#    1346             " repo on your local machine. Make sure you have read the code there to avoid malicious use, then"
#    1347             " set the option `trust_remote_code=True` to remove this error."
#    1348         )
#    1349 _check_library_imports(name=self.name, library_imports=library_imports)
#    1350 module_path, hash = _load_importable_file(
#    1351     dynamic_modules_path=dynamic_modules_path,
#    1352     module_namespace="datasets",
#    1353     subdirectory_name=hash,
#    1354     name=self.name,
#    1355 )
#
# ValueError: Loading super_glue requires you to execute the dataset script in that repo on your local machine. Make sure you have read the code there to avoid malicious use, then set the option `trust_remote_code=True` to remove this error.

# %% [markdown]
# ## 按照数据集划分进行加载

# %%
dataset = load_dataset("madao33/new-title-chinese", split="train")
dataset

# %%
dataset = load_dataset("madao33/new-title-chinese", split="train[10:100]")
dataset

# %%
dataset = load_dataset("madao33/new-title-chinese", split="train[:50%]")
dataset

# %%
dataset = load_dataset("madao33/new-title-chinese", split=["train[:50%]", "train[50%:]"])
dataset

# %% [markdown]
# ## 查看数据集

# %%
datasets = load_dataset("madao33/new-title-chinese")
datasets

# %%
datasets["train"][0]

# %%
datasets["train"][:2]

# %%
datasets["train"]["title"][:5]

# %%
datasets["train"].column_names

# %%
datasets["train"].features

# %% [markdown]
# ## 数据集划分

# %%
dataset = datasets["train"]
dataset.train_test_split(test_size=0.1)

# %%
dataset = boolq_dataset["train"]
dataset.train_test_split(test_size=0.1, stratify_by_column="label")     # 分类数据集可以按照比例划分

# %% [markdown]
# ## 数据选取与过滤

# %%
# 选取
datasets["train"].select([0, 1])

# %%
# 过滤
filter_dataset = datasets["train"].filter(lambda example: "中国" in example["title"])

# %%
filter_dataset["title"][:5]

# %% [markdown]
# ## 数据映射

# %%
def add_prefix(example):
    example["title"] = 'Prefix: ' + example["title"]
    return example

# %%
prefix_dataset = datasets.map(add_prefix)
prefix_dataset["train"][:10]["title"]

# %%
from transformers import AutoTokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-chinese")
def preprocess_function(example, tokenizer=tokenizer):
    model_inputs = tokenizer(example["content"], max_length=512, truncation=True)
    labels = tokenizer(example["title"], max_length=32, truncation=True)
    # label就是title编码的结果
    model_inputs["labels"] = labels["input_ids"]
    return model_inputs

# %%
processed_datasets = datasets.map(preprocess_function)
processed_datasets

# %%
processed_datasets = datasets.map(preprocess_function, num_proc=4)
processed_datasets

# %%
processed_datasets = datasets.map(preprocess_function, batched=True)
processed_datasets

# %%
processed_datasets = datasets.map(preprocess_function, batched=True, remove_columns=datasets["train"].column_names)
processed_datasets

# %% [markdown]
# ## 保存与加载

# %%
processed_datasets.save_to_disk("./processed_data")

# %%
processed_datasets = load_from_disk("./processed_data")
processed_datasets

# %% [markdown]
# # 加载本地数据集

# %% [markdown]
# ## 直接加载文件作为数据集

# %%
dataset = load_dataset("csv", data_files="./ChnSentiCorp_htl_all.csv", split="train")
dataset

# %%
dataset = Dataset.from_csv("./ChnSentiCorp_htl_all.csv")
dataset

# %% [markdown]
# ## 加载文件夹内全部文件作为数据集

# %%
dataset = load_dataset("csv", data_files=["./all_data/ChnSentiCorp_htl_all.csv", "./all_data/ChnSentiCorp_htl_all copy.csv"], split='train')
dataset

# %% [markdown]
# ## 通过预先加载的其他格式转换加载数据集

# %%
import pandas as pd

data = pd.read_csv("./ChnSentiCorp_htl_all.csv")
data.head()

# %%
dataset = Dataset.from_pandas(data)
dataset

# %%
# List格式的数据需要内嵌{}，明确数据字段
data = [{"text": "abc"}, {"text": "def"}]
# data = ["abc", "def"]
Dataset.from_list(data)

# %% [markdown]
# ## 通过自定义加载脚本加载数据集

# %%
load_dataset("json", data_files="./cmrc2018_trial.json", field="data")

# %%
dataset = load_dataset("./load_script.py", split="train")
dataset

# %%
dataset[0]

# %% [markdown]
# # Dataset with DataCollator

# %%
from transformers import  DataCollatorWithPadding

# %%
dataset = load_dataset("csv", data_files="./ChnSentiCorp_htl_all.csv", split='train')
dataset = dataset.filter(lambda x: x["review"] is not None)
dataset

# %%
def process_function(examples):
    tokenized_examples = tokenizer(examples["review"], max_length=128, truncation=True)
    tokenized_examples["labels"] = examples["label"]
    return tokenized_examples

# %%
tokenized_dataset = dataset.map(process_function, batched=True, remove_columns=dataset.column_names)
tokenized_dataset

# %%
print(tokenized_dataset[:3])

# %%
collator = DataCollatorWithPadding(tokenizer=tokenizer)

# %%
from torch.utils.data import DataLoader

# %%
dl = DataLoader(tokenized_dataset, batch_size=4, collate_fn=collator, shuffle=True)

# %%
num = 0
for batch in dl:
    print(batch["input_ids"].size())
    num += 1
    if num > 10:
        break
